# %%
import pandas as pd

# %%
data=pd.read_csv("C:/Users/sanoj/TRAINEE/automated-review-rating-system/data/kaggle/Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products_May19.csv")

# %%
data.head(1)
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
#
#                                                 name                  asins  \
# 0  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
#
#           brand                                         categories  \
# 0  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
#
#   primaryCategories                                          imageURLs  \
# 0   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
#
#                                                 keys  ... reviews.didPurchase  \
# 0  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
#
#   reviews.doRecommend reviews.id reviews.numHelpful reviews.rating  \
# 0                 NaN        NaN                NaN              3
#
#                                   reviews.sourceURLs  \
# ...

# %%
data.isnull().sum()
# Out:
# id                         0
# dateAdded                  0
# dateUpdated                0
# name                       0
# asins                      0
# brand                      0
# categories                 0
# primaryCategories          0
# imageURLs                  0
# keys                       0
# manufacturer               0
# manufacturerNumber         0
# reviews.date               0
# reviews.dateSeen           0
# reviews.didPurchase    28323
# reviews.doRecommend    12246
# reviews.id             28291
# reviews.numHelpful     12217
# reviews.rating             0
# reviews.sourceURLs         0
# reviews.text               0
# reviews.title              0
# reviews.username           5
# sourceURLs                 0
# dtype: int64

# %%
data.shape
# Out:
# (28332, 24)

# %%
data.dtypes
# Out:
# id                      object
# dateAdded               object
# dateUpdated             object
# name                    object
# asins                   object
# brand                   object
# categories              object
# primaryCategories       object
# imageURLs               object
# keys                    object
# manufacturer            object
# manufacturerNumber      object
# reviews.date            object
# reviews.dateSeen        object
# reviews.didPurchase     object
# reviews.doRecommend     object
# reviews.id             float64
# reviews.numHelpful     float64
# reviews.rating           int64
# reviews.sourceURLs      object
# reviews.text            object
# reviews.title           object
# reviews.username        object
# sourceURLs              object
# dtype: object

# %%
data.columns.tolist()
# Out:
# ['id',
#  'dateAdded',
#  'dateUpdated',
#  'name',
#  'asins',
#  'brand',
#  'categories',
#  'primaryCategories',
#  'imageURLs',
#  'keys',
#  'manufacturer',
#  'manufacturerNumber',
#  'reviews.date',
#  'reviews.dateSeen',
#  'reviews.didPurchase',
#  'reviews.doRecommend',
#  'reviews.id',
#  'reviews.numHelpful',
#  'reviews.rating',
#  'reviews.sourceURLs',
#  'reviews.text',
#  'reviews.title',
#  'reviews.username',
#  'sourceURLs']

# %%
df=data.copy()

# %%
df = df[['reviews.title','reviews.text','reviews.date','reviews.rating','categories','brand','name']]

# %%
df.head(1)
# Out:
#                                        reviews.title  \
# 0  ... 3 of them and one of the item is bad quali...
#
#                                         reviews.text  \
# 0  I order 3 of them and one of the item is bad q...
#
#                reviews.date  reviews.rating  \
# 0  2017-03-02T00:00:00.000Z               3
#
#                                           categories         brand  \
# 0  AA,AAA,Health,Electronics,Health & Household,C...  Amazonbasics
#
#                                                 name
# 0  AmazonBasics AAA Performance Alkaline Batterie...

# %%
import matplotlib.pyplot as plt

# %%
##how many reviews of each brand
df['brand'].value_counts()
# Out:
# brand
# Amazon          16153
# Amazonbasics    12169
# AmazonBasics       10
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# reviews.title     object
# reviews.text      object
# reviews.date      object
# reviews.rating     int64
# categories        object
# brand             object
# name              object
# dtype: object

# %%
df['brand'].value_counts().plot(kind='bar',figsize=(10,5))
plt.title("number of reviews per brand")
plt.xlabel('Brand')
plt.ylabel('number of reviews')
plt.show()

# %%
##review rating percentage

df['reviews.rating'].value_counts().plot(kind='pie',figsize=(5,5))
plt.title("percentage of review.rating")
plt.show()

# %%
##hiatograms of review rating
# 
df['reviews.rating'].plot(kind='hist',bins=5)
plt.title("histograms of review rating")
plt.xlabel("Rating")
plt.show()

# %%
#scatter plot
plt.figure(figsize=(10,5))
plt.scatter(df['reviews.date'],df['reviews.rating'],alpha=0.5)
plt.title("scatter plot of review dDate vs Rating")
plt.xlabel('Review Date')
plt.ylabel('Rating')
plt.show()
